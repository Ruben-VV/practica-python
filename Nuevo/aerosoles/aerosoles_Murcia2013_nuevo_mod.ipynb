# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
#import scipy.misc
from scipy.stats import norm, t, chi2, sem
#from scipy.stats import *
import pandas as pd

import aeronettools as at
import aeronettools2 as at2
#import aeronettools_pynb as at3
from aeronettools_pynb import extract_aeronet_data

from IPython.display import display
from IPython.core.pylabtools import figsize, getfigs
from numpy import *
from math import factorial
import scipy.misc
from scipy.stats import *

# %% [raw]
# Se añade la carpeta 'funciones' al PYTHONPATCH

# %%
import sys
sys.path.append('../funciones')
from fun_bootstrap import *
from fun_plothist import *
import fun_bootstrap2 as b2
import fun_bootstrap_mod as bm

# %% [raw]
# Añadimos la ruta de la carpeta 'funciones' donde tenemos todos los scripts al PYTHONPATH (LINUX)

# %% [raw]
# %%!
# export pwd0=$PWD
# cd ../funciones
# export PYTHONPATH=$PYTHONPATH:$PWD
# echo $PYTHONPATH
# cd $pwd0

# %% [raw]
# Otra manera de hacer lo anterior es usando rutas relativas, teniendo en cuenta que la carpeta donde esta este notebook y la carpeta 'funciones' estan en el mismo directorio

# %% [raw]
# %%!
# export PYTHONPATH=$PYTHONPATH:../funciones

# %%
# Autocarga del modulo aeronettools_pynb
# %load_ext autoreload
# %aimport aeronettools_pynb
# %aimport aeronettools
# %aimport aeronettools2
#%aimport fun_bootstrap
# %aimport fun_bootstrap2
# %aimport fun_bootstrap_mod
# %aimport fun_plothist
# %autoreload 1

# %% [raw]
# http://ipython.org/ipython-doc/stable/config/extensions/autoreload.html
# http://www.reddit.com/r/Python/comments/rsfsi/tutorial_spend_30_seconds_setting_up/

# %%
# Comparaciones en los scripts para extraer los datos

import os
if os.environ.get( "USERNAME" ) == 'Ruben':
    FILE = '130501_130531_Murcia.lev15'
else:
    FILE = '/spred/pn32/Renovables/Red/Aeronet/lev15/130501_130531_Murcia.lev15'
    
file_aeronet_Murcia = FILE
df_out_Murcia = extract_aeronet_data(file_aeronet_Murcia)
print df_out_Murcia.shape
print at.extract_aeronet_data(file_aeronet_Murcia).shape
print at2.extract_aeronet_data(file_aeronet_Murcia).shape
# Out:
# aeronettools_pynb.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_day['pre'] = abs(df_day['datetime'].diff())
# aeronettools_pynb.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_day['post'] = abs(df_day['datetime'].diff(periods=-1))
# C:\Anaconda\envs\OLD\lib\site-packages\pandas\util\decorators.py:81: FutureWarning: the 'cols' keyword is deprecated, use 'subset' instead
#   warnings.warn(msg, FutureWarning)
# (164, 2)
# (103, 2)
# aeronettools.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_day['pre'] = abs(df_day['datetime'].diff())
# aeronettools.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_day['post'] = abs(df_day['datetime'].diff(periods=-1))
# aeronettools2.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_day['pre'] = abs(df_day['datetime'].diff())
# (131, 2)
# aeronettools2.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_day['post'] = abs(df_day['datetime'].diff(periods=-1))

# %% [raw]
# Kolmogorov-Smirnov Test
# http://www.mathwave.com/help/easyfit/html/analyses/goodness_of_fit/kolmogorov-smirnov.html
# http://www.real-statistics.com/tests-normality-and-symmetry/statistical-tests-normality-symmetry/kolmogorov-smirnov-test/
# ## https://it.mathworks.com/matlabcentral/newsreader/view_thread/48698

# %% [raw]
# Kolmogorov-Smirnov Test
# Rechazamos la hipótesis nula de que nuestra distribución se ajusta a una distribución teórica si:
#     D > D_crit = D_n-alpha
#     p < alpha (nivel de significacion)
#
#
#
# http://www.real-statistics.com/tests-normality-and-symmetry/statistical-tests-normality-symmetry/kolmogorov-smirnov-test/
# http://www.real-statistics.com/statistics-tables/kolmogorov-smirnov-table/
# http://www.jstatsoft.org/v08/i18/paper

# %% [raw]
# El script 'distribution-check.py' comprueba los datos del fichero que le pasemos (fichero que tiene que tener solo números y un dato por línea) y representa el histograma de los datos y las distribuciones de probabilidad con un valor p más alto del Test K-S. El histograma está normalizado.
# Los scripts 'distribution-check-2.py' y 'distribution-check-2n.py' son modificaciones para comprobar menos distribuciones. El script 'distribution-check-2n.py' no está normalizado.
# Están en la carpeta 'funciones'.

# %% [raw]
# La función fun_plothist pinta el histograma y la curva ajustada de la distribución que quieras.
# Para la distribución normal hace el contraste de hipótesis con el valor D y p para un nivel de confianza del 95%
# Para el resto sólo con el valor p

# %% [markdown]
# # Murcia 2013

# %%
## Con la función extract_aeronet_data
import os
if os.environ.get( "USERNAME" ) == 'Ruben':
    #FILE = '130101_131231_Murcia_aeronet.lev15'
    FILE = '130101_131231_Murcia.lev15'
else:
    FILE = '/spred/pn32/Renovables/Red/Aeronet/lev15/130101_131231_Murcia.lev15'

file_aeronet_Murcia = FILE
df_out_Murcia = extract_aeronet_data(file_aeronet_Murcia)
df_out_Murcia['month'] = df_out_Murcia.index.month

# %%
df_out_Murcia.to_csv('AOT_500_mod.data', sep='\n', columns=['AOT_500'], index=False,header=False)
#df_out_Murcia.to_csv('AOT_500_mod.data', sep='\n', cols=['AOT_500'], index=False,header=False)  # versiones antiguas de pandas

# %%
# %run ../funciones/distribution-check-2.py --file AOT_500_mod.data --verbose --plot --top 5
# Out:
# reading data in file  AOT_500_mod.data ... done
# norm            p: 0.0                   D: 0.114640502252
# beta            p: 0.00174873120367      D: 0.0425980047044
# chi             p: 6.9507281375e-07      D: 0.0619308705122
# chi2            p: 0.00283480192932      D: 0.0411085047774
# gamma           p: 0.00283124308239      D: 0.0411124480063
# t               p: 0.0                   D: 0.11906490016
# uniform         p: 0.0                   D: 0.5261846497
# -------------------------------------------------------------------
# Top 5
# -------------------------------------------------------------------
# 1    chi2             	p:  0.00283480192932 	D:  0.0411085047774
# 2    gamma            	p:  0.00283124308239 	D:  0.0411124480063
# 3    beta             	p:  0.00174873120367 	D:  0.0425980047044
# 4    chi              	p:  6.9507281375e-07 	D:  0.0619308705122
# 5    norm             	p:  0.0 	D:  0.114640502252

# %%
# %run ../funciones/distribution-check-2n.py --file AOT_500_mod.data --verbose --plot --top 5
# Out:
# reading data in file  AOT_500_mod.data ... done
# norm            p: 0.0                   D: 0.114640502252
# beta            p: 0.00174873120367      D: 0.0425980047044
# chi             p: 6.9507281375e-07      D: 0.0619308705122
# chi2            p: 0.00283480192932      D: 0.0411085047774
# gamma           p: 0.00283124308239      D: 0.0411124480063
# t               p: 0.0                   D: 0.11906490016
# uniform         p: 0.0                   D: 0.5261846497
# -------------------------------------------------------------------
# Top 5
# -------------------------------------------------------------------
# 1    chi2             	p:  0.00283480192932 	D:  0.0411085047774
# 2    gamma            	p:  0.00283124308239 	D:  0.0411124480063
# 3    beta             	p:  0.00174873120367 	D:  0.0425980047044
# 4    chi              	p:  6.9507281375e-07 	D:  0.0619308705122
# 5    norm             	p:  0.0 	D:  0.114640502252

# %%
aodMen_Murcia = [df_out_Murcia[df_out_Murcia['month']==i]['AOT_500'].mean() for i in range(1,13)]
dataAODmen_Murcia = [len(df_out_Murcia[df_out_Murcia['month']==i]['AOT_500']) for i in range(1,13)]
df_Murcia = pd.DataFrame({'AODmean_Murcia':aodMen_Murcia, 'number of AOD data':dataAODmen_Murcia })

pylab.figure(figsize=(17,5))
ax = plt.subplot(121)
#ax = df_Murcia.plot(y = 'AODmean_Murcia', marker='.')
ax.plot(df_Murcia.index.values, df_Murcia['AODmean_Murcia'], marker='.')
ax2 = df_Murcia['number of AOD data'].plot(kind = 'bar', secondary_y=True, color ='white', 
                                           align='center')
#ax2 =df_Murcia.plot(y = 'number of AOD data', secondary_y=True)

ax.set_ylabel("AOD monthly mean", fontsize=12)
ax2.set_ylabel("number of AOD data", fontsize=12)

#ax.set_ylim(-150,200)
width = 0.3
ind = np.arange(len(dataAODmen_Murcia))
#rects1 = ax2.bar(ind, dataAODmen_Murcia, width, color='white', align='center')
xTickMarks = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep',
               'oct', 'nov', 'dec']
ax.set_xticks(ind)
ax.set_ylim(0,0.25)
ax2.set_ylim(0,1000)
xtickNames = ax.set_xticklabels(xTickMarks) 
ax.set_xlim(-1,12)
ax2.set_xlim(-1,12)
                
#bar_label(rects1, dataAODmen_Murcia)
ax.set_title('Murcia2013')


# Histogram and K-S Test
ax = plt.subplot(122)
PlotHist(df_out_Murcia['AOT_500'], bin=np.arange(0,0.75,0.02), cdf="norm")
# Out:
# norm            p: 0.0                   D: 0.114640502252
# D critic (alpha=0.05):   0.000703933747412
# H0: La distribución se ajusta a una distribución norm
# Se rechaza H0 al nivel de significación del 5.0%

# %% [raw]
# More tests
# http://statsmodels.sourceforge.net/devel/install.html
#
# (http://stackoverflow.com/questions/7903977/implementing-a-kolmogorov-smirnov-test-in-python-scipy)

# %%
x = df_out_Murcia['AOT_500'].values

# find mean 95% CI and 100,000 bootstrap samples
stat_mean, ci_mean = bootstrap(x,"mean")
obs_mean = np.mean(x)

print "Mean of sample data: \n", obs_mean
pylab.figure(figsize=(18,4))
pylab.subplot(121)
plot_bootstrap(stat_mean, ci_mean[0])
pylab.axvline(obs_mean, c='black')

pylab.subplot(122)
pylab.plot(range(1,len(x)+1), x, '.-')
pylab.title("Plot of Data")
# Out:
# Mean of sample data:
# 0.133793077381
# Bootstrapped 95% confidence intervals of Mean
# Low:
#  0.129491578416
# High: 0.138185706522
# --------------------------------------------------

# %%
x = df_out_Murcia['AOT_500'].values

# find mean 95% CI and 100,000 bootstrap samples
stat_mean, ci_mean = bm.bootstrap2(x,statistic=np.mean)
obs_mean = np.mean(x)

print "Mean of sample data: \n", obs_mean
pylab.figure(figsize=(18,4))
pylab.subplot(121)
bm.plot_bootstrap2(stat_mean, ci_mean)
pylab.axvline(obs_mean, c='black')

pylab.subplot(122)
pylab.plot(range(1,len(x)+1), x, '.-')
pylab.title("Plot of Data")
# Out:
# Mean of sample data:
# 0.133793077381
# Bootstrapped 95% confidence intervals of Mean
# Low:
#  0.12948947412
# High: 0.138133497153
# --------------------------------------------------

# %%
x = df_out_Murcia['AOT_500'].values

# find mean 95% CI and 100,000 bootstrap samples
ci_mean, stat_mean = b2.ci(x, np.mean, method='pi')
obs_mean = np.mean(x)

print "Mean of sample data: \n", obs_mean
pylab.figure(figsize=(18,4))
pylab.subplot(121)
b2.plot_bootstrap(stat_mean, ci_mean)
pylab.axvline(obs_mean, c='black')

pylab.subplot(122)
pylab.plot(range(1,len(x)+1), x, '.-')
pylab.title("Plot of Data")
# Out:
# Mean of sample data:
# 0.133793077381
# Bootstrapped 95% confidence intervals of Mean
# Low:
#  0.129529488354
# High: 0.138101291149
# --------------------------------------------------

# %%
#x = df_out_Murcia['AOT_500'].values

aodMen_Murcia = [df_out_Murcia[df_out_Murcia['month']==i]['AOT_500'].mean() for i in range(1,13)]
dataAODmen_Murcia = [len(df_out_Murcia[df_out_Murcia['month']==i]['AOT_500']) for i in range(1,13)]
df_Murcia = pd.DataFrame({'AODmean_Murcia':aodMen_Murcia, 'number of AOD data':dataAODmen_Murcia })

#Calculo de los Intervalos de Confianza del Bootstraping y la distribucion Normal
lista_Murcia = [df_out_Murcia[df_out_Murcia['month']==i]['AOT_500'].values for i in range(1,13)]
errlow, errhigh = [], []

for i in xrange(len(lista_Murcia)):
    stat_mean, ci_mean = bootstrap(lista_Murcia[i],"mean")
    errlow.append(ci_mean[0][0])
    errhigh.append(ci_mean[0][1])
df = df_Murcia.copy()
df['errlo'], df['errhi'] = errlow, errhigh


pylab.figure()
#ax = df_Murcia.plot(y = 'AODmean_Murcia')
ax = plt.subplot(111)
ax.errorbar(range(12), df['AODmean_Murcia'], yerr=[list(df['AODmean_Murcia'] - df['errlo']), 
                                                   list(df['errhi'] - df['AODmean_Murcia'])], fmt='.-') 
#ax = df.errorbar(y = 'AODmean_Murcia')

ax2 = df_Murcia['number of AOD data'].plot(kind = 'bar', secondary_y=True, color ='white', 
                                           align='center')
#ax2 =df_Murcia.plot(y = 'number of AOD data', secondary_y=True)

##ax.set_ylabel("AOD monthly mean", fontsize=12)
ax2.set_ylabel("number of AOD data", fontsize=12)

#ax.set_ylim(-150,200)
width = 0.3
ind = np.arange(len(dataAODmen_Murcia))
#rects1 = ax2.bar(ind, dataAODmen_Murcia, width, color='white', align='center')
xTickMarks = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep',
           'oct', 'nov', 'dec']
ax.set_xticks(ind)
ax.set_ylim(0,0.25)
ax2.set_ylim(0,1000)
xtickNames = ax.set_xticklabels(xTickMarks)
ax.set_xlim(-1,12)
ax2.set_xlim(-1,12)
            
#bar_label(rects1, dataAODmen_Murcia)
ax.set_title('Murcia2013') 

print df
# Out:
#     AODmean_Murcia  number of AOD data     errlo     errhi
# 0         0.038217                  93  0.035064  0.041522
# 1         0.058233                 130  0.046523  0.072091
# 2         0.056438                 111  0.050983  0.062393
# 3         0.100686                 104  0.091722  0.109829
# 4         0.131374                 164  0.118175  0.145589
# 5         0.158229                 267  0.147172  0.170152
# 6         0.184190                 330  0.174883  0.193611
# 7         0.207565                 224  0.192472  0.222530
# 8         0.175863                 139  0.163185  0.188935
# 9         0.137523                 147  0.126520  0.148846
# 10        0.049802                 148  0.046090  0.053976
# 11        0.100353                  75  0.085016  0.116142

# %%
x = df_out_Murcia['AOT_500'].values
stat_mean, ci_mean = bootstrap(x,"mean")
stat_mean2, ci_mean2 = bootstrap2(x, statistic=np.mean)
stat_mean3, ci_mean3 = bm.bootstrap2(x, statistic=np.mean)
print ci_mean
print ci_mean2
print ci_mean3
# Out:
# [[0.12946229451345756, 0.13818490527950308]]
# [0.12948360533126294, 0.13816061904761906]
# [0.12956700517598344, 0.13826947877846793]

# %% [markdown]
# ### Realizamos la media diaria y procedemos a realizar lo mismo que antes

# %%
df_out_Murcia_2 = extract_aeronet_data(file_aeronet_Murcia)
df_out_Murcia_2['month'] = df_out_Murcia_2.index.month
#df_out_Murcia_2['day'] = df_out_Murcia_2.index.day
# Diary mean
df_out_Murcia_2 = df_out_Murcia_2.resample('D', how='mean').dropna()
#df_out_Murcia_2 = df_out_Murcia_2.resample('D', how='mean').dropna(subset = ['AOT_500'])


aodMen_Murcia = [df_out_Murcia_2[df_out_Murcia_2['month']==i]['AOT_500'].mean() for i in range(1,13)]
dataAODmen_Murcia = [len(df_out_Murcia_2[df_out_Murcia_2['month']==i]['AOT_500']) for i in range(1,13)]
df_Murcia_2 = pd.DataFrame({'AODmean_Murcia':aodMen_Murcia, 'number of AOD data':dataAODmen_Murcia })

x = df_out_Murcia_2['AOT_500'].values

# %%
pylab.figure(figsize=(17,5))
ax = plt.subplot(121)
ax.plot(df_Murcia_2.index.values, df_Murcia_2['AODmean_Murcia'], marker='.')
ax2 = df_Murcia_2['number of AOD data'].plot(kind = 'bar', secondary_y=True, color ='white', 
                                           align='center')

ax.set_ylabel("AOD monthly mean", fontsize=12)
ax2.set_ylabel("number of AOD data", fontsize=12)

#ax.set_ylim(-150,200)
width = 0.3
ind = np.arange(len(dataAODmen_Murcia))
#rects1 = ax2.bar(ind, dataAODmen_Murcia, width, color='white', align='center')
xTickMarks = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep',
               'oct', 'nov', 'dec']
ax.set_xticks(ind)
ax.set_ylim(0,0.25)
ax2.set_ylim(0,200)
xtickNames = ax.set_xticklabels(xTickMarks) 
ax.set_xlim(-1,12)
ax2.set_xlim(-1,12)
                
#bar_label(rects1, dataAODmen_Murcia)
ax.set_title('Murcia2013')


# Histogram and K-S Test
ax = plt.subplot(122)
PlotHist(df_out_Murcia_2['AOT_500'], bin=np.arange(0,0.75,0.05), cdf="norm")
# Out:
# norm            p: 0.000302973049927     D: 0.137324693895
# D critic (alpha=0.05):   0.00591304347826
# H0: La distribución se ajusta a una distribución norm
# Se rechaza H0 al nivel de significación del 5.0%

# %%
x = df_out_Murcia_2['AOT_500'].values

# find mean 95% CI and 100,000 bootstrap samples
stat_mean, ci_mean = bootstrap(x,"mean")
#ci_low, ci_high, stat_mean = bootstrap2(x,statistic=np.mean)
obs_mean = np.mean(x)

print "Mean of sample data: \n", obs_mean
pylab.figure(figsize=(18,4))
pylab.subplot(121)
plot_bootstrap(stat_mean, ci_mean[0])
#plot_bootstrap([stat_mean], [ci_low, ci_high])
pylab.axvline(obs_mean, c='black')

pylab.subplot(122)
pylab.plot(range(1,len(x)+1), x, '.-')
pylab.title("Plot of Data")
# Out:
# Mean of sample data:
# 0.126635420109
# Bootstrapped 95% confidence intervals of Mean
# Low:
#  0.114893644856
# High: 0.138677879216
# --------------------------------------------------

# %%
#Calculo de los Intervalos de Confianza del Bootstraping y la distribucion Normal
lista_Murcia = [df_out_Murcia_2[df_out_Murcia_2['month']==i]['AOT_500'].values for i in range(1,13)]
errlow, errhigh = [], []

for i in xrange(len(lista_Murcia)):
    stat_mean, ci_mean = bootstrap(lista_Murcia[i],"mean")
    errlow.append(ci_mean[0][0])
    errhigh.append(ci_mean[0][1])
df_2 = df_Murcia_2.copy()
df_2['errlo'], df_2['errhi'] = errlow, errhigh


pylab.figure()
ax = plt.subplot(111)
ax.errorbar(range(12), df_2['AODmean_Murcia'], yerr=[list(df_2['AODmean_Murcia'] - df_2['errlo']), 
                                                   list(df_2['errhi'] - df_2['AODmean_Murcia'])], 
            fmt='.-') 

ax2 = df_Murcia_2['number of AOD data'].plot(kind = 'bar', secondary_y=True, color ='white', 
                                           align='center')

##ax.set_ylabel("AOD monthly mean", fontsize=12)
ax2.set_ylabel("number of AOD data", fontsize=12)

#ax.set_ylim(-150,200)
width = 0.3
ind = np.arange(len(dataAODmen_Murcia))
#rects1 = ax2.bar(ind, dataAODmen_Murcia, width, color='white', align='center')
xTickMarks = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep',
           'oct', 'nov', 'dec']
ax.set_xticks(ind)
ax.set_ylim(0,0.3)
ax2.set_ylim(0,200)
xtickNames = ax.set_xticklabels(xTickMarks)
ax.set_xlim(-1,12)
ax2.set_xlim(-1,12)
            
#bar_label(rects1, dataAODmen_Murcia)
ax.set_title('Murcia2013') 

print df_2
# Out:
#     AODmean_Murcia  number of AOD data     errlo     errhi
# 0         0.038550                  16  0.031718  0.046130
# 1         0.063014                  19  0.037049  0.101963
# 2         0.056433                  15  0.042655  0.074097
# 3         0.099716                  13  0.076721  0.123542
# 4         0.129985                  18  0.096142  0.167264
# 5         0.161463                  25  0.128724  0.199812
# 6         0.186645                  29  0.158176  0.215667
# 7         0.217589                  24  0.173802  0.260903
# 8         0.176782                  17  0.142666  0.211177
# 9         0.138072                  21  0.111302  0.166584
# 10        0.050707                  21  0.042516  0.061511
# 11        0.099041                  12  0.062355  0.137160

# %%
df_out_Murcia_2.to_csv('AOT_500_2_mod.data', sep='\n', columns=['AOT_500'], index=False, header=False)
# df_out_Murcia_2.to_csv('AOT_500_2_mod.data', sep='\n', cols=['AOT_500'], index=False, header=False)  # versiones antiguas de pandas

# %%
# %run ../funciones/distribution-check-2n.py --file AOT_500_2_mod.data --verbose --plot --top 5
# Out:
# reading data in file  AOT_500_2_mod.data ... done
# norm            p: 0.000302973049927     D: 0.137324693895
# beta            p: 0.30486703191         D: 0.063228144178
# chi             p: 0.24002619163         D: 0.0671672237362
# chi2            p: 0.00180297632176      D: 0.122588516449
# gamma           p: 0.482126809773        D: 0.054900920216
# t               p: 0.000568287397724     D: 0.132317179897
# uniform         p: 4.38293845662e-12     D: 0.239400964974
# -------------------------------------------------------------------
# Top 5
# -------------------------------------------------------------------
# 1    gamma            	p:  0.482126809773 	D:  0.054900920216
# 2    beta             	p:  0.30486703191 	D:  0.063228144178
# 3    chi              	p:  0.24002619163 	D:  0.0671672237362
# 4    chi2             	p:  0.00180297632176 	D:  0.122588516449
# 5    t                	p:  0.000568287397724 	D:  0.132317179897
